# %%
import numpy as np
import pandas as pd
import cv2
import PIL
import pytesseract

# %%
img_cv = cv2.imread('./Selected/084.jpeg')

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
type(img_cv)
# Out:
# numpy.ndarray

# %%
img_pl = PIL.Image.open('./Selected/084.jpeg')

# %%
type(img_pl)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
img_pl
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x352>

# %% [markdown]
# ### Text from Image

# %%
text_cv = pytesseract.image_to_string(img_cv)

# %%
import pytesseract

# %%
text_cv = pytesseract.image_to_string(img_cv)

# %%
print(text_cv)
# Out:
# P. Balamurugan
# Manager-Sales
# 95000 46823,
#
#
#
#
#
# MANALI LUBRICANTS Pvt. Ltd
#
# Mfrs. Of EHV Transformer oil, industrial, automotive
# lubes & petroleum specialties.
#
# 24, SIDCO Industrial Estate, Thirumudivakkam,Chennai-600044.
# Tel: 044-24780648,58, Fax:044-24780658,
# E-mail: manal_lubs@yahoo.com / manaliubs@gmail com

# %%
text_p1 = pytesseract.image_to_string(img_pl)

# %%
print(text_p1)
# Out:
# P. Balamurugan
# Manager-Sales
# 95000 46823,
#
#
#
#
#
# MANALI LUBRICANTS Pvt. Ltd
#
# Mfrs. Of EHV Transformer oil, industrial, automotive
# lubes & petroleum specialties.
#
# 24, SIDCO Industrial Estate, Thirumudivakkam, Chennai-600044.
# Tel; 044-24780648,58, Fax:044-24780658,
# E-mail: manal_lubs@yahoo.com / manaliubs@gmail com

# %% [markdown]
# ### Image To Data

# %%
data = pytesseract.image_to_data(img_cv)

# %%
#data.split('\n')
dataList = list(map(lambda x: x.split('\t'),data.split('\n')))
df = pd.DataFrame(dataList[1:],columns=dataList[0])

# %%
df.head(10)
# Out:
#   level page_num block_num par_num line_num word_num left top width height  \
# 0     1        1         0       0        0        0    0   0   600    352
# 1     2        1         1       0        0        0  444  10   144     52
# 2     3        1         1       1        0        0  444  10   144     52
# 3     4        1         1       1        1        0  444  10   143     19
# 4     5        1         1       1        1        1  444  10    14     15
# 5     5        1         1       1        1        2  467  10   120     19
# 6     4        1         1       1        2        0  479  33   109     16
# 7     5        1         1       1        2        1  479  33   109     16
# 8     4        1         1       1        3        0  495  50    93     12
# 9     5        1         1       1        3        1  495  50    44     12
#
#   conf           text
# 0   -1
# 1   -1
# 2   -1
# 3   -1
# 4   79             P.
# 5   92    Balamurugan
# 6   -1
# 7   88  Manager-Sales
# 8   -1
# 9   68          95000

# %%
df.dropna(inplace=True) #drop the missing values in rows
col_int = ['level','page_num','block_num','par_num','line_num','word_num','left','top','width','height','conf']
df[col_int] = df[col_int].astype(int)

# %%
df.dtypes
# Out:
# level         int64
# page_num      int64
# block_num     int64
# par_num       int64
# line_num      int64
# word_num      int64
# left          int64
# top           int64
# width         int64
# height        int64
# conf          int64
# text         object
# dtype: object

# %%
image = img_cv.copy()
level = 'word'
for l,x,y,w,h,c,txt in df [['level','left','top','width','height','conf','text']].values:
    #print(l,x,y,w,h,c)
    if level == 'page':
        if l == 1:
            cv2.rectangle(image,(x,y),(x+w,y+h),(0,0,0),2)
        else:
            continue

    elif level == 'block':
        if l == 2:
            cv2.rectangle(image,(x,y),(x+w,y+h),(255,0,0),2)
        else:
            continue

    elif level == 'para':
        if l == 3:
            cv2.rectangle(image,(x,y),(x+w,y+h),(0,255,0),2)
        else:
            continue
    elif level == 'line':
        if l == 4:
            cv2.rectangle(image,(x,y),(x+w,y+h),(0,0,255),2)
        else:
            continue
    elif level == 'word':
        if l == 5:
            cv2.rectangle(image,(x,y),(x+w,y+h),(0,255,0),2)
            cv2.putText(image,txt,(x,y),cv2.FONT_HERSHEY_PLAIN,1,(255,0,0),2)
        else:
            continue

cv2.imshow("bounding box",image)
cv2.waitKey()
cv2.destroyAllWindows()
